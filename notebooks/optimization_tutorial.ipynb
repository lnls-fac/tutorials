# %%
import logging
import sys

import numpy as np
import matplotlib.pyplot as mplt

from apsuite.optimization.rcds import RCDS, RCDSParams

root = logging.getLogger()
root.setLevel(logging.INFO)
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)
root.addHandler(handler)

# %%
# %matplotlib qt5

# %% [markdown]
# # Examples of usage

# %% [markdown]
# ## Simple paraboloid minimization with RCDS

# %% [markdown]
# Let's set up the optimzation for the following problem
#
# $$ \mathrm{x}_{\text{min}} = \text{argmin}_{\mathrm{x}} f(\mathrm{x}) $$
#
# where
#
# $$f(\mathrm{x}) = \mathrm{x}^\intercal \mathrm{x} + \xi = \sum_i x_i ^2 + \xi$$
#
# and $$\xi \sim \mathcal{N}(\mu = 0, \sigma = \hat{\sigma})$$.
#
# The objective function landscape is a paraboloid with a stocastic component simulating exprimental noise with standard deviaation $\hat{\sigma}$. Will assume $\hat{\sigma}=10^{-2}$, and focus on the two-dimensional problem, whith $\mathrm{x}\in[-3, -5] \times [4, 6]$

# %% [markdown]
# We'll create a class named `ParaboiloidOptimization`, which will be a child class from the `RCDS` class. The reason we do this is because the optimzation problem at sight might have additional parameters or specific routines.  For examples, take a look a the `injbo_optimize_rcds.py`, or `rcds_posang.py`, or `dynap_opt_rcds.py` scripts in the `apsuite/commisslib` submodule

# %% [markdown]
# ### Create the optimization problem classes
#
# We create the `Params` class and the optimization class

# %%
class ParaboloidOptimizationParams(RCDSParams):

    def __init__(self):
        super().__init__()

    # in this case the params class is basically the
    # default class inherited from RCDSParams
    # it contains only parameters relevant to the RCDS
    # algorithm itself

    # but maybe the optimzation expeiment depend on several
    # other parameters, such as a minimum reading from a given sensor
    # in order to proceed with optimzation, maybe the name of the
    # optimization variables & their upper/lower limits etc

# %%
class ParaboloidOptimization(RCDS):
    """Minimize a noisy paraboloid."""

    def __init__(self, use_thread=True, isonline=True):
        super().__init__(use_thread, isonline)
        self.params = ParaboloidOptimizationParams()


    def objective_function(self, pos):
        return np.dot(pos, pos) + self.params.noise_level * np.random.randn()

# %% [markdown]
# We instantiate the class object

# %%
opt = ParaboloidOptimization(use_thread=False, isonline=False)

# %% [markdown]
# and can check its default parameters

# %%
print(opt.params)
# Out:
# initial_stepsize              :      0.010
# noise_level                   :      0.000
# tolerance                     :      0.000
# orthogonality_threshold       :      0.900
# update_search_directions      : True
# linescan_num_pts              :          6
# linescan_min_pts_fit          :          4
# outlier_method                : Xiaobiao
# outlier_max_err_factor        :      3.000
# outlier_percentile_limit      :      0.250
# max_number_iters              :        100
# max_number_evals              :       1000
# boundary_policy               : ToNaN
#
# Positions
# limit_lower
# limit_upper
# initial_position
# Search Dir. 0

# %% [markdown]
# nex we set the desired parameters

# %%
# problem-specific params
opt.params.limit_lower = [-3, -5]
opt.params.limit_upper = [4, 6]
# if the workflow of the objective function evaluations
# or other routines in the main optimzation class depend
# on additional parameters, they could be set here as well

# RCDS params
# these are the parameters RCDS requires for its internal
# logic and operations
opt.params.max_number_evals = 500
opt.params.max_number_iters = 5
opt.params.initial_stepsize = 0.0100
opt.params.noise_level = 1e-2
opt.params.tolerance = 1e-5

# initial position refers to the initial point in the
# optimaztion variables space
# you could set it to a particular value or sample
# the available search space ramdomly, as below
opt.params.initial_position = np.random.uniform(
    low=opt.params.limit_lower, high=opt.params.limit_upper)

# search directions along whith to start the line
# minimizations. It is a matrix with each row standing for a
# given direction
opt.params.initial_search_directions = np.eye(2)

# %%
print(opt.params)
# Out:
# initial_stepsize              :      0.010
# noise_level                   :      0.010
# tolerance                     :      0.000
# orthogonality_threshold       :      0.900
# update_search_directions      : True
# linescan_num_pts              :          6
# linescan_min_pts_fit          :          4
# outlier_method                : Xiaobiao
# outlier_max_err_factor        :      3.000
# outlier_percentile_limit      :      0.250
# max_number_iters              :          5
# max_number_evals              :        500
# boundary_policy               : ToNaN
#
# Positions               Dir. 0         Dir. 1
# limit_lower               -3             -5
# limit_upper                4              6
# initial_position        -0.411          -4.74
# Search Dir. 0              1              0
# Search Dir. 1              0              1

# %% [markdown]
# **launch the optimzation run**
#
# will stop if either the `max_number_iters` or the `max_number_evals` are reached, or even if the
# changes in the objective function are less than `tol`

# %%
opt.start()
# Out:
# Starting Optimization. Initial ObjFun: 22.6
#
# Iteration 0001/0005
#     Bracketing Dir. 1:  Delta = [-0.0571, 0.0924]   Objfun = 22.5
#     Linescan in Dir. 1:    Delta = 0.00351   Objfun = 22.5
#     Updated ObjFun largest decrease 0.164.
#
#     Bracketing Dir. 2:  Delta = [-0.45, 0.1]   Objfun = 0.0537
#     Linescan in Dir. 2:    Delta = -0.0189   Objfun = 0.00404
#     Updated ObjFun largest decrease 22.455.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0001: Final ObjFun = 0.00404
#
# Iteration 0002/0005
#     Bracketing Dir. 1:  Delta = [-0.0407, 0.0545]   Objfun = -0.00463
#     Linescan in Dir. 1:    Delta = 0.00623   Objfun = 0.00448
#
#     Bracketing Dir. 2:  Delta = [-0.0112, 0.0251]   Objfun = -0.00103
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00602   Objfun = 0.00442
#     Updated ObjFun largest decrease 0.000.
#
#     Checking extension point.
#     Replacing direction 2
#         Bracket result:  Delta = [-0.0545, 0.0112]   Objfun = 0.000571
#         Linescan result: Delta = 0.00602   Objfun = 0.00124
# End of iteration 0002: Final ObjFun = 0.00124
#
# Iteration 0003/0005
#     Bracketing Dir. 1:  Delta = [-0.0455, 0.0339]   Objfun = -0.00975
#     Linescan in Dir. 1:    Delta = -0.00734   Objfun = 0.00106
#     Updated ObjFun largest decrease 0.000.
#
#     Bracketing Dir. 2:  Delta = [-0.0339, 0.0455]   Objfun = 0.000201
#     Linescan in Dir. 2:    Delta = 0.00773   Objfun = 0.00797
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.920
# End of iteration 0003: Final ObjFun = 0.00797
#
# Iteration 0004/0005
#     Bracketing Dir. 1:  Delta = [-0.0379, 0.0282]   Objfun = 0.00402
#     Linescan in Dir. 1:    Delta = -0.00611   Objfun = 0.00524
#     Updated ObjFun largest decrease 0.003.
#
#     Bracketing Dir. 2:  Delta = [-0.0204, 0.0457]   Objfun = -0.000271
#     Linescan in Dir. 2:    Delta = 0.00975   Objfun = -0.00518
#     Updated ObjFun largest decrease 0.010.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0004: Final ObjFun = -0.00518
#
# Iteration 0005/0005
#     Bracketing Dir. 1:  Delta = [-0.0721, 0.0275]   Objfun = -0.00518
#     Linescan in Dir. 1:    Delta = 0.000311   Objfun = -2.55e-05
#
#     Bracketing Dir. 2:  Delta = [-0.0235, 0.0316]   Objfun = -0.0187
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00548   Objfun = -0.00852
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0005: Final ObjFun = -0.00852
#
#  Finished!
# Number of iterations: 0005
# Number of evaluations: 0088
# f_0 = 22.6
# f_min = -0.0187
# f_min/f0 = -0.000825

# %% [markdown]
# accompany the optimzation history

# %%
fig, ax = opt.plot_history()

# %%
fig, ax = opt.plot_knobspace_slice()

# %% [markdown]
# ## Rosenbrock function minimzation with RCDS
# a slightly more complicated objective function

# %% [markdown]
# - objective
# $$f(x_0, \dots, x_i) = \sum_{i=0}^N 100(x_{i+1} - x_i^2) + (1 - x_i)^2$$
#
# For 2 dimensions, $N=2$,
# - global minimum at $x_g = (1, 1)$, with $f(x_g) = 0$

# %%
class RosenbrockOptimizationParams(RCDSParams):

    def __init__(self):
        super().__init__()

    # in this case the params class is basically the
    # default class inherited from RCDSParams
    # it contains only parameters relevant to the RCDS
    # algorithm itself

    # but maybe the optimzation expeiment depend on several
    # other parameters, such as a minimum reading from a given sensor
    # in order to proceed with optimzation, maybe the name of the
    # optimization variables & their upper/lower limits etc

# %%
class RosenbrockOptimization(RCDS):
    """Minimize a noisy paraboloid."""

    def __init__(self, use_thread=True, isonline=False):
        super().__init__(use_thread, isonline)
        self.params = RosenbrockOptimizationParams()


    def objective_function(self, pos):
        obj = 0
        for i in range(len(pos)-1):
            obj += 100 * (pos[i+1] - pos[i]**2)**2
            obj += (1 - pos[i])**2 + 1e-2 * np.random.randn()
        return obj

# %%
opt = RosenbrockOptimization(use_thread=False, isonline=False)

# %%
print(opt.params)
# Out:
# initial_stepsize              :      0.010
# noise_level                   :      0.000
# tolerance                     :      0.000
# orthogonality_threshold       :      0.900
# update_search_directions      : True
# linescan_num_pts              :          6
# linescan_min_pts_fit          :          4
# outlier_method                : Xiaobiao
# outlier_max_err_factor        :      3.000
# outlier_percentile_limit      :      0.250
# max_number_iters              :        100
# max_number_evals              :       1000
# boundary_policy               : ToNaN
#
# Positions
# limit_lower
# limit_upper
# initial_position
# Search Dir. 0

# %%
# problem-specific params
opt.params.limit_lower = [-4, -4]
opt.params.limit_upper = [4, 4]

# RCDS params
opt.params.max_number_evals = 10000
opt.params.max_number_iters = 1000
opt.params.initial_stepsize = 0.0100
opt.params.noise_level = 1e-2
opt.params.tolerance = 1e-4


#opt.params.initial_position = np.random.uniform(
#    low=opt.params.limit_lower, high=opt.params.limit_upper)

opt.params.initial_position = [-1., -1.] # just a really bad starting point

opt.params.initial_search_directions = np.eye(2)

# %%
print(opt.params)
# Out:
# initial_stepsize              :      0.010
# noise_level                   :      0.010
# tolerance                     :      0.000
# orthogonality_threshold       :      0.900
# update_search_directions      : True
# linescan_num_pts              :          6
# linescan_min_pts_fit          :          4
# outlier_method                : Xiaobiao
# outlier_max_err_factor        :      3.000
# outlier_percentile_limit      :      0.250
# max_number_iters              :       1000
# max_number_evals              :      10000
# boundary_policy               : ToNaN
#
# Positions               Dir. 0         Dir. 1
# limit_lower               -4             -4
# limit_upper                4              4
# initial_position          -1             -1
# Search Dir. 0              1              0
# Search Dir. 1              0              1

# %%
opt.start()
# Out:
# Starting Optimization. Initial ObjFun: 404
#
# Iteration 0001/1000
#     Bracketing Dir. 1:  Delta = [-0.15, 0.1]   Objfun = 108
#     Linescan in Dir. 1:    Delta = -0.0258   Objfun = 90.5
#     Updated ObjFun largest decrease 313.499.
#
#     Bracketing Dir. 2:  Delta = [-0.15, 0.1]   Objfun = 4.88
#     Linescan in Dir. 2:    Delta = -0.0245   Objfun = 1.02
#
#     Checking extension point.
#     Replacing direction 1
#         Bracket result:  Delta = [-0.00833, 0.00833]   Objfun = 1.02
#         Linescan result: Delta = -0.0245   Objfun = 1
# End of iteration 0001: Final ObjFun = 1
#
# Iteration 0002/1000
#     Bracketing Dir. 1:  Delta = [-0.00694, 0.00694]   Objfun = 1
#     Linescan in Dir. 1:    Delta = -0.00145   Objfun = 0.99
#     Updated ObjFun largest decrease 0.012.
#
#     Bracketing Dir. 2:  Delta = [-0.00694, 0.00694]   Objfun = 0.99
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00193   Objfun = 0.978
#     Updated ObjFun largest decrease 0.012.
#
#     Checking extension point.
#     Replacing direction 2
#         Bracket result:  Delta = [-0.0182, 0.0294]   Objfun = 0.756
#         Linescan result: Delta = 0.00193   Objfun = 0.6
# End of iteration 0002: Final ObjFun = 0.6
#
# Iteration 0003/1000
#     Bracketing Dir. 1:  Delta = [-0.00579, 0.00579]   Objfun = 0.6
#     Linescan in Dir. 1:    Delta = 0.00125   Objfun = 0.699
#
#     Bracketing Dir. 2:  Delta = [-0.00579, 0.0152]   Objfun = 0.699
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00381   Objfun = 0.688
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0003: Final ObjFun = 0.688
#
# Iteration 0004/1000
#     Bracketing Dir. 1:  Delta = [-0.00482, 0.00482]   Objfun = 0.688
#     Linescan in Dir. 1:    Delta = 0.00156   Objfun = 0.689
#
#     Bracketing Dir. 2:  Delta = [-0.00965, 0.0078]   Objfun = 0.669
#     Linescan in Dir. 2:    Delta = -0.00116   Objfun = 0.671
#     Updated ObjFun largest decrease 0.018.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 0.917
# End of iteration 0004: Final ObjFun = 0.671
#
# Iteration 0005/1000
#     Bracketing Dir. 1:  Delta = [-0.00402, 0.0105]   Objfun = 0.671
#     Linescan in Dir. 1:    Delta = 0.00174   Objfun = 0.655
#     Updated ObjFun largest decrease 0.016.
#
#     Bracketing Dir. 2:  Delta = [-0.00804, 0.0065]   Objfun = 0.632
#     Linescan in Dir. 2:    Delta = -0.000353   Objfun = 0.633
#     Updated ObjFun largest decrease 0.023.
#
#     Checking extension point.
#     Replacing direction 2
#         Bracket result:  Delta = [-0.0105, 0.017]   Objfun = 0.526
#         Linescan result: Delta = -0.000353   Objfun = 0.522
# End of iteration 0005: Final ObjFun = 0.522
#
# Iteration 0006/1000
#     Bracketing Dir. 1:  Delta = [-0.00335, 0.00542]   Objfun = 0.466
#     Linescan in Dir. 1:    Delta = -0.000628   Objfun = 0.475
#     Updated ObjFun largest decrease 0.047.
#
#     Bracketing Dir. 2:  Delta = [-0.00877, 0.0142]   Objfun = 0.442
#     Linescan in Dir. 2:    Delta = -0.00144   Objfun = 0.424
#     Updated ObjFun largest decrease 0.050.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 0.958
# End of iteration 0006: Final ObjFun = 0.424
#
# Iteration 0007/1000
#     Bracketing Dir. 1:  Delta = [-0.00558, 0.00452]   Objfun = 0.407
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.00072   Objfun = 0.403
#     Updated ObjFun largest decrease 0.022.
#
#     Bracketing Dir. 2:  Delta = [-0.00558, 0.0163]   Objfun = 0.385
#     Linescan in Dir. 2:    Delta = 0.00168   Objfun = 0.366
#     Updated ObjFun largest decrease 0.036.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 0.940
# End of iteration 0007: Final ObjFun = 0.366
#
# Iteration 0008/1000
#     Bracketing Dir. 1:  Delta = [-0.00465, 0.00376]   Objfun = 0.36
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000752   Objfun = 0.351
#     Updated ObjFun largest decrease 0.015.
#
#     Bracketing Dir. 2:  Delta = [-0.00841, 0.00985]   Objfun = 0.348
#     Linescan in Dir. 2:    Delta = -0.00169   Objfun = 0.338
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.960
# End of iteration 0008: Final ObjFun = 0.338
#
# Iteration 0009/1000
#     Bracketing Dir. 1:  Delta = [-0.00388, 0.00314]   Objfun = 0.329
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000247   Objfun = 0.319
#     Updated ObjFun largest decrease 0.019.
#
#     Bracketing Dir. 2:  Delta = [-0.00194, 0.00314]   Objfun = 0.288
#     Linescan in Dir. 2:    Delta = 0.000591   Objfun = 0.301
#
#     Checking extension point.
#     Replacing direction 1
#         Bracket result:  Delta = [-0.0348, 0.0563]   Objfun = 0.12
#         Linescan result: Delta = 0.000591   Objfun = -0.0375
# End of iteration 0009: Final ObjFun = -0.0375
#
# Iteration 0010/1000
#     Bracketing Dir. 1:  Delta = [-0.00162, 0.00162]   Objfun = -0.0375
#     Linescan in Dir. 1:    Delta = 0.000209   Objfun = 0.0675
#
#     Bracketing Dir. 2:  Delta = [-0.00162, 0.00162]   Objfun = 0.0675
#     Linescan in Dir. 2:    Delta = 5.98e-05   Objfun = 0.11
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0010: Final ObjFun = 0.11
#
# Iteration 0011/1000
#     Bracketing Dir. 1:  Delta = [-0.00352, 0.00352]   Objfun = 0.11
#     Linescan in Dir. 1:    Delta = 0.000194   Objfun = 0.127
#
#     Bracketing Dir. 2:  Delta = [-0.00487, 0.0228]   Objfun = 0.114
#     Linescan in Dir. 2:    Delta = 0.00754   Objfun = 0.108
#     Updated ObjFun largest decrease 0.019.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0011: Final ObjFun = 0.108
#
# Iteration 0012/1000
#     Bracketing Dir. 1:  Delta = [-0.00769, 0.00112]   Objfun = 0.108
#     Linescan in Dir. 1:    Delta = -0.00106   Objfun = 0.111
#
#     Bracketing Dir. 2:  Delta = [-0.0212, 0.019]   Objfun = 0.0993
#     Linescan in Dir. 2:    Delta = 0.00252   Objfun = 0.102
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 0.985
# End of iteration 0012: Final ObjFun = 0.102
#
# Iteration 0013/1000
#     Bracketing Dir. 1:  Delta = [-0.00151, 0.00338]   Objfun = 0.0865
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000624   Objfun = 0.0966
#     Updated ObjFun largest decrease 0.006.
#
#     Bracketing Dir. 2:  Delta = [-0.00885, 0.0143]   Objfun = 0.0895
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00288   Objfun = 0.0884
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 1.000
# End of iteration 0013: Final ObjFun = 0.0884
#
# Iteration 0014/1000
#     Bracketing Dir. 1:  Delta = [-0.00534, 0.00204]   Objfun = 0.0884
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.00128   Objfun = 0.0908
#
#     Bracketing Dir. 2:  Delta = [-0.00456, 0.0148]   Objfun = 0.063
#     Linescan in Dir. 2:    Delta = 0.00555   Objfun = 0.0748
#     Updated ObjFun largest decrease 0.016.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 0.988
# End of iteration 0014: Final ObjFun = 0.0748
#
# Iteration 0015/1000
#     Bracketing Dir. 1:  Delta = [-0.00445, 0.00445]   Objfun = 0.0748
#     Linescan in Dir. 1:    Delta = -0.000895   Objfun = 0.0659
#     Updated ObjFun largest decrease 0.009.
#
#     Bracketing Dir. 2:  Delta = [-0.00445, 0.0116]   Objfun = 0.0659
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00285   Objfun = 0.0678
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.982
# End of iteration 0015: Final ObjFun = 0.0678
#
# Iteration 0016/1000
#     Bracketing Dir. 1:  Delta = [-0.00425, 0.00317]   Objfun = 0.0642
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.00132   Objfun = 0.0616
#     Updated ObjFun largest decrease 0.006.
#
#     Bracketing Dir. 2:  Delta = [-0.00971, 0.00971]   Objfun = 0.0616
#     Linescan in Dir. 2:    Delta = 0.00112   Objfun = 0.0602
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0016: Final ObjFun = 0.0602
#
# Iteration 0017/1000
#     Bracketing Dir. 1:  Delta = [-0.00264, 0.00354]   Objfun = 0.0542
#     Linescan in Dir. 1:    Delta = 0.000206   Objfun = 0.058
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-0.00854, 0.00264]   Objfun = 0.0448
#     Linescan in Dir. 2:    Delta = -0.00165   Objfun = 0.0614
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0017: Final ObjFun = 0.0614
#
# Iteration 0018/1000
#     Bracketing Dir. 1:  Delta = [-0.00197, 0.00576]   Objfun = 0.0537
#     Linescan in Dir. 1:    Delta = -0.000419   Objfun = 0.0572
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.0022, 0.018]   Objfun = 0.0522
#     Linescan in Dir. 2:    Delta = 0.00286   Objfun = 0.0602
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0018: Final ObjFun = 0.0602
#
# Iteration 0019/1000
#     Bracketing Dir. 1:  Delta = [-0.00562, 0.00215]   Objfun = 0.0602
#     Linescan in Dir. 1:    Delta = -0.00121   Objfun = 0.0561
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.00562, 0.0147]   Objfun = 0.0561
#     Linescan in Dir. 2:    Delta = 0.0028   Objfun = 0.0665
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.955
# End of iteration 0019: Final ObjFun = 0.0665
#
# Iteration 0020/1000
#     Bracketing Dir. 1:  Delta = [-0.000683, 0.0011]   Objfun = 0.0228
#     Linescan in Dir. 1:    Delta = 6.52e-05   Objfun = 0.0529
#     Updated ObjFun largest decrease 0.014.
#
#     Bracketing Dir. 2:  Delta = [-0.0123, 0.0123]   Objfun = 0.0529
#     Linescan in Dir. 2:    Delta = -0.00234   Objfun = 0.0543
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0020: Final ObjFun = 0.0543
#
# Iteration 0021/1000
#     Bracketing Dir. 1:  Delta = [-0.00333, 0.00206]   Objfun = 0.0535
#     Linescan in Dir. 1:    Delta = 0.000176   Objfun = 0.0613
#
#     Bracketing Dir. 2:  Delta = [-0.00964, 0.0108]   Objfun = 0.0548
#     Linescan in Dir. 2:    Delta = 0.00123   Objfun = 0.0601
#     Updated ObjFun largest decrease 0.001.
#
#     Checking extension point.
#     Replacing direction 2
#         Bracket result:  Delta = [-0.00368, 0.00412]   Objfun = 0.0555
#         Linescan result: Delta = 0.00123   Objfun = 0.0609
# End of iteration 0021: Final ObjFun = 0.0609
#
# Iteration 0022/1000
#     Bracketing Dir. 1:  Delta = [-0.00372, 0.00278]   Objfun = 0.0518
#     Linescan in Dir. 1:    Delta = -0.000464   Objfun = 0.0565
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.00325, 0.00325]   Objfun = 0.0565
#     Linescan in Dir. 2:    Delta = 0.000387   Objfun = 0.0661
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0022: Final ObjFun = 0.0661
#
# Iteration 0023/1000
#     Bracketing Dir. 1:  Delta = [-0.00231, 0.0031]   Objfun = 0.0547
#     Linescan in Dir. 1:    Delta = 0.00081   Objfun = 0.062
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.0031, 0.0067]   Objfun = 0.052
#     Linescan in Dir. 2:    Delta = 0.000173   Objfun = 0.0623
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.921
# End of iteration 0023: Final ObjFun = 0.0623
#
# Iteration 0024/1000
#     Bracketing Dir. 1:  Delta = [-0.00259, 0.00193]   Objfun = 0.0502
#     Linescan in Dir. 1:    Delta = -0.00035   Objfun = 0.0636
#
#     Bracketing Dir. 2:  Delta = [-0.00213, 0.00604]   Objfun = 0.0505
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000673   Objfun = 0.0531
#     Updated ObjFun largest decrease 0.010.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 1.000
# End of iteration 0024: Final ObjFun = 0.0531
#
# Iteration 0025/1000
#     Bracketing Dir. 1:  Delta = [-0.0026, 0.00421]   Objfun = 0.0486
#     Linescan in Dir. 1:    Delta = 2.83e-06   Objfun = 0.0524
#     Updated ObjFun largest decrease 0.001.
#
#     Bracketing Dir. 2:  Delta = [-0.00116, 0.00564]   Objfun = 0.0473
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00314   Objfun = 0.0579
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0025: Final ObjFun = 0.0579
#
# Iteration 0026/1000
#     Bracketing Dir. 1:  Delta = [-0.00314, 0.00254]   Objfun = 0.0557
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -9.78e-05   Objfun = 0.0523
#     Updated ObjFun largest decrease 0.006.
#
#     Bracketing Dir. 2:  Delta = [-0.000969, 0.0047]   Objfun = 0.0363
#     Linescan in Dir. 2:    Delta = 0.00192   Objfun = 0.0405
#     Updated ObjFun largest decrease 0.012.
#
#     Checking extension point.
#     Replacing direction 2
#         Bracket result:  Delta = [-0.0012, 0.0101]   Objfun = 0.0365
#         Linescan result: Delta = 0.00192   Objfun = 0.0399
# End of iteration 0026: Final ObjFun = 0.0399
#
# Iteration 0027/1000
#     Bracketing Dir. 1:  Delta = [-0.00292, 0.00181]   Objfun = 0.0333
#     Linescan in Dir. 1:    Delta = -0.00022   Objfun = 0.0376
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-0.00138, 0.00765]   Objfun = 0.0269
#         # outliers removed = 2,
#     Linescan in Dir. 2:    Delta = 0   Objfun = 0.0269
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0027: Final ObjFun = 0.0269
#
# Iteration 0028/1000
#     Bracketing Dir. 1:  Delta = [-0.00269, 0.000318]   Objfun = 0.0182
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0   Objfun = 0.0192
#     Updated ObjFun largest decrease 0.008.
#
#     Bracketing Dir. 2:  Delta = [-0.00243, 0.000832]   Objfun = 0.0167
#     Linescan in Dir. 2:    Delta = -0.000554   Objfun = 0.0309
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0028: Final ObjFun = 0.0309
#
# Iteration 0029/1000
#     Bracketing Dir. 1:  Delta = [-0.000132, 0.00622]   Objfun = 0.0309
#     Linescan in Dir. 1:    Delta = 0.000535   Objfun = 0.0334
#
#     Bracketing Dir. 2:  Delta = [-0.000296, 0.00627]   Objfun = 0.0293
#     Linescan in Dir. 2:    Delta = 0.00142   Objfun = 0.0399
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0029: Final ObjFun = 0.0399
#
# Iteration 0030/1000
#     Bracketing Dir. 1:  Delta = [-0.00547, 0.00169]   Objfun = 0.0211
#     Linescan in Dir. 1:    Delta = -0.00099   Objfun = 0.0355
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.00716, 0.0116]   Objfun = 0.0232
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -2.97e-05   Objfun = 0.0196
#     Updated ObjFun largest decrease 0.016.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0030: Final ObjFun = 0.0196
#
# Iteration 0031/1000
#     Bracketing Dir. 1:  Delta = [-0.00141, 0.000276]   Objfun = 0.0166
#     Linescan in Dir. 1:    Delta = -0.000453   Objfun = 0.0272
#
#     Bracketing Dir. 2:  Delta = [-0.0113, 0.0113]   Objfun = 0.0272
#     Linescan in Dir. 2:    Delta = 0.000373   Objfun = 0.0313
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0031: Final ObjFun = 0.0313
#
# Iteration 0032/1000
#     Bracketing Dir. 1:  Delta = [-0.00135, 0.00363]   Objfun = 0.0192
#     Linescan in Dir. 1:    Delta = -1.19e-06   Objfun = 0.0345
#
#     Bracketing Dir. 2:  Delta = [-0.0034, 0.00962]   Objfun = 0.0277
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00188   Objfun = 0.0341
#     Updated ObjFun largest decrease 0.000.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0032: Final ObjFun = 0.0341
#
# Iteration 0033/1000
#     Bracketing Dir. 1:  Delta = [-0.000103, 0.00306]   Objfun = 0.0115
#     Linescan in Dir. 1:    Delta = 0.000204   Objfun = 0.0339
#     Updated ObjFun largest decrease 0.000.
#
#     Bracketing Dir. 2:  Delta = [-0.000708, 0.00344]   Objfun = 0.0191
#     Linescan in Dir. 2:    Delta = 0.00174   Objfun = 0.0391
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0033: Final ObjFun = 0.0391
#
# Iteration 0034/1000
#     Bracketing Dir. 1:  Delta = [-0.00652, 0.00252]   Objfun = 0.0232
#     Linescan in Dir. 1:    Delta = -0.000956   Objfun = 0.0192
#     Updated ObjFun largest decrease 0.020.
#
#     Bracketing Dir. 2:  Delta = [-0.00654, 0.00654]   Objfun = 0.0192
#     Linescan in Dir. 2:    Delta = -1.96e-05   Objfun = 0.0133
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0034: Final ObjFun = 0.0133
#
# Iteration 0035/1000
#     Bracketing Dir. 1:  Delta = [-0.00208, 0.000795]   Objfun = 0.0133
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = -0.000795   Objfun = 0.018
#
#     Bracketing Dir. 2:  Delta = [-0.000116, 0.0143]   Objfun = 0.018
#     Linescan in Dir. 2:    Delta = 0.00407   Objfun = 0.0295
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0035: Final ObjFun = 0.0295
#
# Iteration 0036/1000
#     Bracketing Dir. 1:  Delta = [-0.000759, 0.00107]   Objfun = 0.0154
#     Linescan in Dir. 1:    Delta = 3.03e-05   Objfun = 0.0251
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.0119, 0.00454]   Objfun = 0.0251
#     Linescan in Dir. 2:    Delta = -0.00283   Objfun = 0.0327
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0036: Final ObjFun = 0.0327
#
# Iteration 0037/1000
#     Bracketing Dir. 1:  Delta = [-0.00357, 0.00166]   Objfun = 0.0128
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = 0.000763   Objfun = 0.0312
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-0.00999, 0.00371]   Objfun = 0.0169
#     Linescan in Dir. 2:    Delta = -0.0026   Objfun = 0.0229
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0037: Final ObjFun = 0.0229
#
# Iteration 0038/1000
#     Bracketing Dir. 1:  Delta = [-0.00114, 0.00322]   Objfun = 0.0201
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = 0.00127   Objfun = 0.0412
#
#     Bracketing Dir. 2:  Delta = [-3.54e-05, 5.74e-05]   Objfun = 0.0353
#     Linescan in Dir. 2:    Delta = 1.53e-05   Objfun = 0.0302
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0038: Final ObjFun = 0.0302
#
# Iteration 0039/1000
#     Bracketing Dir. 1:  Delta = [-0.00588, 0.00139]   Objfun = 0.0213
#     Linescan in Dir. 1:    Delta = -0.000292   Objfun = 0.0365
#
#     Bracketing Dir. 2:  Delta = [-0.00703, 0.0179]   Objfun = 0.0194
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000524   Objfun = 0.0157
#     Updated ObjFun largest decrease 0.021.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0039: Final ObjFun = 0.0157
#
# Iteration 0040/1000
#     Bracketing Dir. 1:  Delta = [-0.00219, 6.8e-06]   Objfun = 0.0157
#     Linescan in Dir. 1:    Delta = -0.000614   Objfun = 0.0312
#
#     Bracketing Dir. 2:  Delta = [-0.00572, 0.015]   Objfun = 0.0131
#     Linescan in Dir. 2:    Delta = 0.00182   Objfun = 0.0247
#     Updated ObjFun largest decrease 0.007.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0040: Final ObjFun = 0.0247
#
# Iteration 0041/1000
#     Bracketing Dir. 1:  Delta = [-1.13e-05, 0.00477]   Objfun = 0.0189
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000288   Objfun = 0.0279
#
#     Bracketing Dir. 2:  Delta = [-2.05e-05, 0.000682]   Objfun = 0.0133
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000305   Objfun = 0.0165
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0041: Final ObjFun = 0.0165
#
# Iteration 0042/1000
#     Bracketing Dir. 1:  Delta = [-0.00398, 0.00152]   Objfun = 0.0165
#     Linescan in Dir. 1:    Delta = -0.000539   Objfun = 0.0213
#
#     Bracketing Dir. 2:  Delta = [-9.45e-06, 0.0104]   Objfun = 0.0101
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00335   Objfun = 0.0258
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0042: Final ObjFun = 0.0258
#
# Iteration 0043/1000
#     Bracketing Dir. 1:  Delta = [-0.00331, 0.00128]   Objfun = 0.0214
#     Linescan in Dir. 1:    Delta = -0.000623   Objfun = 0.0272
#
#     Bracketing Dir. 2:  Delta = [-0.00128, 0.00205]   Objfun = 0.00694
#     Linescan in Dir. 2:    Delta = -0.000744   Objfun = 0.0159
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0043: Final ObjFun = 0.0159
#
# Iteration 0044/1000
#     Bracketing Dir. 1:  Delta = [-0.00274, 0.00108]   Objfun = 0.0119
#     Linescan in Dir. 1:    Delta = -0.000689   Objfun = 0.0107
#     Updated ObjFun largest decrease 0.005.
#
#     Bracketing Dir. 2:  Delta = [-0.00765, 0.00684]   Objfun = 0.00782
#     Linescan in Dir. 2:    Delta = 0.00184   Objfun = 0.03
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 0.981
# End of iteration 0044: Final ObjFun = 0.03
#
# Iteration 0045/1000
#     Bracketing Dir. 1:  Delta = [-0.00232, 0.000862]   Objfun = 0.0175
#     Linescan in Dir. 1:    Delta = -0.000487   Objfun = 0.0304
#
#     Bracketing Dir. 2:  Delta = [-0.000339, 0.00197]   Objfun = 0.000622
#     Linescan in Dir. 2:    Delta = -0.000208   Objfun = 0.0128
#     Updated ObjFun largest decrease 0.018.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0045: Final ObjFun = 0.0128
#
# Iteration 0046/1000
#     Bracketing Dir. 1:  Delta = [-0.00203, 0.00181]   Objfun = 0.0104
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000251   Objfun = 0.00997
#     Updated ObjFun largest decrease 0.003.
#
#     Bracketing Dir. 2:  Delta = [-4.56e-06, 0.00503]   Objfun = 0.0047
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00151   Objfun = 0.0107
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0046: Final ObjFun = 0.0107
#
# Iteration 0047/1000
#     Bracketing Dir. 1:  Delta = [-1.11e-05, 0.0016]   Objfun = 0.00978
#     Linescan in Dir. 1:    Delta = 9.11e-05   Objfun = 0.0341
#
#     Bracketing Dir. 2:  Delta = [-1.9e-06, 1.11e-05]   Objfun = -0.002
#     Linescan in Dir. 2:    Delta = 2.06e-06   Objfun = 0.0184
#     Updated ObjFun largest decrease 0.016.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0047: Final ObjFun = 0.0184
#
# Iteration 0048/1000
#     Bracketing Dir. 1:  Delta = [-0.00298, 0.00102]   Objfun = 0.00701
#     Linescan in Dir. 1:    Delta = -0.000167   Objfun = 0.0224
#
#     Bracketing Dir. 2:  Delta = [-0.0035, 7.02e-05]   Objfun = 0.00346
#     Linescan in Dir. 2:    Delta = -0.00163   Objfun = 0.0238
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0048: Final ObjFun = 0.0238
#
# Iteration 0049/1000
#     Bracketing Dir. 1:  Delta = [-0.00109, 0.00293]   Objfun = 0.0172
#     Linescan in Dir. 1:    Delta = 0.001   Objfun = 0.016
#     Updated ObjFun largest decrease 0.008.
#
#     Bracketing Dir. 2:  Delta = [-0.000163, 0.00275]   Objfun = -0.00145
#     Linescan in Dir. 2:    Delta = 0   Objfun = 0.00738
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0049: Final ObjFun = 0.00738
#
# Iteration 0050/1000
#     Bracketing Dir. 1:  Delta = [-0.000115, 0.000946]   Objfun = 0.00118
#     Linescan in Dir. 1:    Delta = 0.000155   Objfun = 0.0267
#
#     Bracketing Dir. 2:  Delta = [-0.000115, 0.00637]   Objfun = 0.000606
#     Linescan in Dir. 2:    Delta = 0.00172   Objfun = 0.0194
#     Updated ObjFun largest decrease 0.007.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0050: Final ObjFun = 0.0194
#
# Iteration 0051/1000
#     Bracketing Dir. 1:  Delta = [-0.00531, 0.000756]   Objfun = 0.0109
#     Linescan in Dir. 1:    Delta = -0.00115   Objfun = 0.0206
#
#     Bracketing Dir. 2:  Delta = [-0.00528, 0.0053]   Objfun = 0.0131
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.00109   Objfun = 0.0174
#     Updated ObjFun largest decrease 0.003.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0051: Final ObjFun = 0.0174
#
# Iteration 0052/1000
#     Bracketing Dir. 1:  Delta = [-0.0044, 0.00169]   Objfun = 0.0138
#     Linescan in Dir. 1:    Delta = 7.91e-05   Objfun = 0.0242
#
#     Bracketing Dir. 2:  Delta = [-0.00441, 0.0044]   Objfun = 0.00392
#     Linescan in Dir. 2:    Delta = -0.000336   Objfun = 0.0115
#     Updated ObjFun largest decrease 0.013.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0052: Final ObjFun = 0.0115
#
# Iteration 0053/1000
#     Bracketing Dir. 1:  Delta = [-1.14e-05, 6.36e-07]   Objfun = 0.0115
#     Linescan in Dir. 1:    Delta = -5.28e-06   Objfun = 0.0127
#
#     Bracketing Dir. 2:  Delta = [-3.72e-06, 2.3e-06]   Objfun = 0.00341
#     Linescan in Dir. 2:    Delta = -9.19e-07   Objfun = 0.0136
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0053: Final ObjFun = 0.0136
#
# Iteration 0054/1000
#     Bracketing Dir. 1:  Delta = [-0.00018, 0.00116]   Objfun = 0.00797
#     Linescan in Dir. 1:    Delta = -7.47e-05   Objfun = 0.0234
#
#     Bracketing Dir. 2:  Delta = [-0.000105, 6.66e-05]   Objfun = -0.00264
#     Linescan in Dir. 2:    Delta = -1.52e-05   Objfun = 0.0066
#     Updated ObjFun largest decrease 0.017.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0054: Final ObjFun = 0.0066
#
# Iteration 0055/1000
#     Bracketing Dir. 1:  Delta = [-0.000975, 0.00255]   Objfun = 0.0066
#     Linescan in Dir. 1:    Delta = 0.000141   Objfun = 0.0244
#
#     Bracketing Dir. 2:  Delta = [-3.47e-06, 0.00668]   Objfun = 0.00791
#     Linescan in Dir. 2:    Delta = 0.000369   Objfun = 0.0267
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0055: Final ObjFun = 0.0267
#
# Iteration 0056/1000
#     Bracketing Dir. 1:  Delta = [-0.000118, 0.000119]   Objfun = -0.00195
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -8.17e-06   Objfun = 0.00715
#     Updated ObjFun largest decrease 0.020.
#
#     Bracketing Dir. 2:  Delta = [-3.68e-07, 0.00557]   Objfun = 0.00715
#     Linescan in Dir. 2:    Delta = 0.00106   Objfun = 0.0319
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 1.000
# End of iteration 0056: Final ObjFun = 0.0319
#
# Iteration 0057/1000
#     Bracketing Dir. 1:  Delta = [-0.000113, 0.00167]   Objfun = 0.0128
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0   Objfun = 0.0127
#     Updated ObjFun largest decrease 0.019.
#
#     Bracketing Dir. 2:  Delta = [-1.61e-06, 3.69e-05]   Objfun = 0.000214
#     Linescan in Dir. 2:    Delta = 1.53e-05   Objfun = 0.0174
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0057: Final ObjFun = 0.0174
#
# Iteration 0058/1000
#     Bracketing Dir. 1:  Delta = [-0.00365, 0.000779]   Objfun = 0.000868
#     Linescan in Dir. 1:    Delta = -0.000529   Objfun = 0.0236
#
#     Bracketing Dir. 2:  Delta = [-4.84e-06, 4.33e-06]   Objfun = 0.00119
#     Linescan in Dir. 2:    Delta = -1.32e-07   Objfun = 0.0191
#     Updated ObjFun largest decrease 0.005.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0058: Final ObjFun = 0.0191
#
# Iteration 0059/1000
#     Bracketing Dir. 1:  Delta = [-0.00322, 0.00322]   Objfun = 0.009
#     Linescan in Dir. 1:    Delta = 2.96e-05   Objfun = 0.0177
#     Updated ObjFun largest decrease 0.001.
#
#     Bracketing Dir. 2:  Delta = [-7.71e-07, 9.02e-07]   Objfun = -0.00406
#     Linescan in Dir. 2:    Delta = 1.72e-07   Objfun = 0.00688
#     Updated ObjFun largest decrease 0.011.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0059: Final ObjFun = 0.00688
#
# Iteration 0060/1000
#     Bracketing Dir. 1:  Delta = [-5.71e-05, 0.00268]   Objfun = 0.00688
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000688   Objfun = 0.018
#
#     Bracketing Dir. 2:  Delta = [-7.87e-06, 6.42e-07]   Objfun = 0.00761
#     Linescan in Dir. 2:    Delta = -3.36e-06   Objfun = 0.0171
#     Updated ObjFun largest decrease 0.001.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0060: Final ObjFun = 0.0171
#
# Iteration 0061/1000
#     Bracketing Dir. 1:  Delta = [-2.03e-06, 0.00224]   Objfun = 0.0167
#     Linescan in Dir. 1:    Delta = 0.000124   Objfun = 0.02
#
#     Bracketing Dir. 2:  Delta = [-5.46e-05, 0.00219]   Objfun = 0.00706
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000212   Objfun = 0.0251
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0061: Final ObjFun = 0.0251
#
# Iteration 0062/1000
#     Bracketing Dir. 1:  Delta = [-0.00417, 0.000713]   Objfun = 0.000254
#     Linescan in Dir. 1:    Delta = -0.000689   Objfun = 0.0142
#     Updated ObjFun largest decrease 0.011.
#
#     Bracketing Dir. 2:  Delta = [-5.91e-06, 2.09e-06]   Objfun = 0.00197
#     Linescan in Dir. 2:    Delta = -2.39e-06   Objfun = 0.0163
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0062: Final ObjFun = 0.0163
#
# Iteration 0063/1000
#     Bracketing Dir. 1:  Delta = [-2.11e-06, 4.35e-07]   Objfun = 0.00467
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -9.7e-07   Objfun = 0.0128
#     Updated ObjFun largest decrease 0.004.
#
#     Bracketing Dir. 2:  Delta = [-0.00156, 0.00407]   Objfun = 0.00898
#     Linescan in Dir. 2:    Delta = 0.00149   Objfun = 0.0149
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 1.000
# End of iteration 0063: Final ObjFun = 0.0149
#
# Iteration 0064/1000
#     Bracketing Dir. 1:  Delta = [-0.00148, 0.0032]   Objfun = 0.00882
#     Linescan in Dir. 1:    Delta = -0.000119   Objfun = 0.0232
#
#     Bracketing Dir. 2:  Delta = [-2.12e-06, 3.43e-06]   Objfun = -0.000173
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 8.42e-07   Objfun = 0.00755
#     Updated ObjFun largest decrease 0.016.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0064: Final ObjFun = 0.00755
#
# Iteration 0065/1000
#     Bracketing Dir. 1:  Delta = [-0.00108, 5.68e-05]   Objfun = 0.000144
#     Linescan in Dir. 1:    Delta = -0.000469   Objfun = 0.0213
#
#     Bracketing Dir. 2:  Delta = [-0.00267, 0.00755]   Objfun = 0.000932
#     Linescan in Dir. 2:    Delta = 0.00202   Objfun = 0.0221
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0065: Final ObjFun = 0.0221
#
# Iteration 0066/1000
#     Bracketing Dir. 1:  Delta = [-9.11e-07, 0.000131]   Objfun = -0.00649
#     Linescan in Dir. 1:    Delta = 5.31e-05   Objfun = 0.0156
#     Updated ObjFun largest decrease 0.007.
#
#     Bracketing Dir. 2:  Delta = [-5.63e-07, 2.52e-07]   Objfun = -0.00879
#     Linescan in Dir. 2:    Delta = -1.65e-07   Objfun = 0.00518
#     Updated ObjFun largest decrease 0.010.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0066: Final ObjFun = 0.00518
#
# Iteration 0067/1000
#     Bracketing Dir. 1:  Delta = [-0.00196, 0.00196]   Objfun = 0.00165
#     Linescan in Dir. 1:    Delta = -0.000117   Objfun = 0.018
#
#     Bracketing Dir. 2:  Delta = [-0.000749, 0.00439]   Objfun = -0.001
#     Linescan in Dir. 2:    Delta = 0.00092   Objfun = 0.00837
#     Updated ObjFun largest decrease 0.010.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0067: Final ObjFun = 0.00837
#
# Iteration 0068/1000
#     Bracketing Dir. 1:  Delta = [-1.49e-07, 0.000624]   Objfun = 0.00487
#     Linescan in Dir. 1:    Delta = 0.000243   Objfun = 0.0192
#
#     Bracketing Dir. 2:  Delta = [-0.0112, 0.00428]   Objfun = 0.00604
#     Linescan in Dir. 2:    Delta = -0.00265   Objfun = 0.0225
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0068: Final ObjFun = 0.0225
#
# Iteration 0069/1000
#     Bracketing Dir. 1:  Delta = [-0.000197, 0.00357]   Objfun = -0.00521
#     Linescan in Dir. 1:    Delta = 7.75e-05   Objfun = 0.019
#     Updated ObjFun largest decrease 0.003.
#
#     Bracketing Dir. 2:  Delta = [-0.000199, 0.000322]   Objfun = -0.00644
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 5.11e-05   Objfun = -0.00181
#     Updated ObjFun largest decrease 0.021.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0069: Final ObjFun = -0.00181
#
# Iteration 0070/1000
#     Bracketing Dir. 1:  Delta = [-1.35e-06, 9.23e-06]   Objfun = -0.00181
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 6.07e-07   Objfun = 0.023
#
#     Bracketing Dir. 2:  Delta = [-1.06e-05, 0.000432]   Objfun = -0.0014
#     Linescan in Dir. 2:    Delta = 6.19e-05   Objfun = 0.00671
#     Updated ObjFun largest decrease 0.016.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0070: Final ObjFun = 0.00671
#
# Iteration 0071/1000
#     Bracketing Dir. 1:  Delta = [-2.39e-08, 7.69e-06]   Objfun = 0.00671
#     Linescan in Dir. 1:    Delta = 3.31e-06   Objfun = 0.0196
#
#     Bracketing Dir. 2:  Delta = [-2.02e-05, 0.00246]   Objfun = -0.00135
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000612   Objfun = 0.0112
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0071: Final ObjFun = 0.0112
#
# Iteration 0072/1000
#     Bracketing Dir. 1:  Delta = [-0.00128, 0.00285]   Objfun = 0.00223
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000402   Objfun = 0.0134
#
#     Bracketing Dir. 2:  Delta = [-0.000115, 0.00195]   Objfun = 0.00178
#     Linescan in Dir. 2:    Delta = 0.000653   Objfun = 0.00707
#     Updated ObjFun largest decrease 0.006.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0072: Final ObjFun = 0.00707
#
# Iteration 0073/1000
#     Bracketing Dir. 1:  Delta = [-5.95e-07, 1.37e-05]   Objfun = -0.000492
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 6.87e-06   Objfun = 0.00198
#     Updated ObjFun largest decrease 0.005.
#
#     Bracketing Dir. 2:  Delta = [-0.000657, 0.0045]   Objfun = 0.00198
#     Linescan in Dir. 2:    Delta = -0.000251   Objfun = 0.00782
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0073: Final ObjFun = 0.00782
#
# Iteration 0074/1000
#     Bracketing Dir. 1:  Delta = [-6.1e-05, 0.000517]   Objfun = 0.000892
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = 0.000401   Objfun = 0.0187
#
#     Bracketing Dir. 2:  Delta = [-0.00143, 0.00232]   Objfun = 0.00602
#     Linescan in Dir. 2:    Delta = -0.000348   Objfun = 0.0131
#     Updated ObjFun largest decrease 0.006.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0074: Final ObjFun = 0.0131
#
# Iteration 0075/1000
#     Bracketing Dir. 1:  Delta = [-0.00319, 0.00113]   Objfun = 0.0112
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.00102   Objfun = 0.0146
#
#     Bracketing Dir. 2:  Delta = [-0.00306, 0.000133]   Objfun = 0.00151
#     Linescan in Dir. 2:    Delta = -0.00139   Objfun = 0.0108
#     Updated ObjFun largest decrease 0.004.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0075: Final ObjFun = 0.0108
#
# Iteration 0076/1000
#     Bracketing Dir. 1:  Delta = [-0.000235, 0.000145]   Objfun = -0.00175
#     Linescan in Dir. 1:    Delta = -4.54e-05   Objfun = 0.0137
#
#     Bracketing Dir. 2:  Delta = [-2.07e-05, 0.000146]   Objfun = 0.000787
#     Linescan in Dir. 2:    Delta = 2.24e-05   Objfun = 0.0132
#     Updated ObjFun largest decrease 0.000.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0076: Final ObjFun = 0.0132
#
# Iteration 0077/1000
#     Bracketing Dir. 1:  Delta = [-0.00217, 0.00217]   Objfun = 0.00206
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000381   Objfun = 0.0142
#
#     Bracketing Dir. 2:  Delta = [-2.52e-06, 0.00568]   Objfun = -0.00224
#     Linescan in Dir. 2:    Delta = 0.00216   Objfun = 0.0222
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0077: Final ObjFun = 0.0222
#
# Iteration 0078/1000
#     Bracketing Dir. 1:  Delta = [-5.63e-06, 0.0018]   Objfun = 0.00537
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000468   Objfun = 0.0299
#
#     Bracketing Dir. 2:  Delta = [-1.47e-05, 0.000249]   Objfun = 0.0101
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 2.37e-05   Objfun = 0.0114
#     Updated ObjFun largest decrease 0.019.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0078: Final ObjFun = 0.0114
#
# Iteration 0079/1000
#     Bracketing Dir. 1:  Delta = [-9.63e-05, 0.00142]   Objfun = 0.00773
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0.000136   Objfun = 0.0182
#
#     Bracketing Dir. 2:  Delta = [-6.89e-07, 1.11e-06]   Objfun = 0.0144
#     Linescan in Dir. 2:    Delta = 1.5e-07   Objfun = 0.0185
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0079: Final ObjFun = 0.0185
#
# Iteration 0080/1000
#     Bracketing Dir. 1:  Delta = [-2.22e-07, 3.52e-07]   Objfun = 0.00626
#     Linescan in Dir. 1:    Delta = 5.75e-08   Objfun = 0.0174
#     Updated ObjFun largest decrease 0.001.
#
#     Bracketing Dir. 2:  Delta = [-0.00532, 0.00658]   Objfun = -0.00089
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = 0.000217   Objfun = 0.00515
#     Updated ObjFun largest decrease 0.012.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0080: Final ObjFun = 0.00515
#
# Iteration 0081/1000
#     Bracketing Dir. 1:  Delta = [-0.0004, 2.64e-08]   Objfun = 0.00515
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000203   Objfun = -0.000438
#     Updated ObjFun largest decrease 0.006.
#
#     Bracketing Dir. 2:  Delta = [-4.74e-07, 8.51e-06]   Objfun = -0.000438
#     Linescan in Dir. 2:    Delta = 1.99e-06   Objfun = 0.0119
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0081: Final ObjFun = 0.0119
#
# Iteration 0082/1000
#     Bracketing Dir. 1:  Delta = [-4.87e-05, 7.87e-05]   Objfun = 0.00241
#     Linescan in Dir. 1:    Delta = 1.79e-06   Objfun = 0.0105
#     Updated ObjFun largest decrease 0.001.
#
#     Bracketing Dir. 2:  Delta = [-4.86e-05, 5.2e-09]   Objfun = 0.000181
#     Linescan in Dir. 2:    Delta = -2.35e-05   Objfun = 0.0113
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0082: Final ObjFun = 0.0113
#
# Iteration 0083/1000
#     Bracketing Dir. 1:  Delta = [-0.000278, 0.00163]   Objfun = 0.00149
#     Linescan in Dir. 1:    Delta = -0.000172   Objfun = 0.00667
#     Updated ObjFun largest decrease 0.005.
#
#     Bracketing Dir. 2:  Delta = [-5.33e-07, 3.32e-07]   Objfun = -0.00514
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -1.24e-07   Objfun = 0.00306
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0083: Final ObjFun = 0.00306
#
# Iteration 0084/1000
#     Bracketing Dir. 1:  Delta = [-0.00159, 4.01e-08]   Objfun = 0.00306
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000696   Objfun = 0.0208
#
#     Bracketing Dir. 2:  Delta = [-0.00159, 0.0109]   Objfun = 0.0113
#     Linescan in Dir. 2:    Delta = 0.00162   Objfun = 0.0235
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0084: Final ObjFun = 0.0235
#
# Iteration 0085/1000
#     Bracketing Dir. 1:  Delta = [-8.93e-08, 2.81e-05]   Objfun = -0.00205
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 1.48e-06   Objfun = 0.00678
#     Updated ObjFun largest decrease 0.017.
#
#     Bracketing Dir. 2:  Delta = [-1.08e-05, 0.00345]   Objfun = -0.00632
#     Linescan in Dir. 2:    Delta = 0.000182   Objfun = -0.00153
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0085: Final ObjFun = -0.00153
#
# Iteration 0086/1000
#     Bracketing Dir. 1:  Delta = [-5.61e-09, 0.000161]   Objfun = -0.00296
#     Linescan in Dir. 1:    Delta = 7.63e-05   Objfun = 0.0149
#
#     Bracketing Dir. 2:  Delta = [-5.61e-09, 2.51e-09]   Objfun = -0.0124
#     Linescan in Dir. 2:    Delta = -1.24e-09   Objfun = 4.68e-05
#     Updated ObjFun largest decrease 0.015.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0086: Final ObjFun = 4.68e-05
#
# Iteration 0087/1000
#     Bracketing Dir. 1:  Delta = [-1.29e-09, 2.32e-08]   Objfun = 4.68e-05
#     Linescan in Dir. 1:    Delta = 1.83e-08   Objfun = -0.00516
#     Updated ObjFun largest decrease 0.005.
#
#     Bracketing Dir. 2:  Delta = [-3.38e-09, 1.29e-09]   Objfun = -0.00516
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -9.17e-10   Objfun = -0.00581
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0087: Final ObjFun = -0.00581
#
# Iteration 0088/1000
#     Bracketing Dir. 1:  Delta = [-2.82e-09, 1.08e-09]   Objfun = -0.00581
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -8.65e-10   Objfun = -0.00581
#     Updated ObjFun largest decrease 0.000.
#
#     Bracketing Dir. 2:  Delta = [-1.08e-09, 1.08e-09]   Objfun = -0.00581
#     Linescan in Dir. 2:    Delta = 9.7e-12   Objfun = 0.00506
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0088: Final ObjFun = 0.00506
#
# Iteration 0089/1000
#     Bracketing Dir. 1:  Delta = [-0.00167, 7.56e-07]   Objfun = 0.00506
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = -0.000244   Objfun = 0.0143
#
#     Bracketing Dir. 2:  Delta = [-1.16e-07, 0.00167]   Objfun = 0.00139
#     Linescan in Dir. 2:    Delta = 0.000696   Objfun = 0.0185
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0089: Final ObjFun = 0.0185
#
# Iteration 0090/1000
#     Bracketing Dir. 1:  Delta = [-1.13e-05, 0.00363]   Objfun = 0.00323
#     Linescan in Dir. 1:    Delta = 0.000274   Objfun = 0.017
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-1.85e-08, 6.17e-07]   Objfun = 0.00103
#     Linescan in Dir. 2:    Delta = 3.08e-07   Objfun = 0.00717
#     Updated ObjFun largest decrease 0.010.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0090: Final ObjFun = 0.00717
#
# Iteration 0091/1000
#     Bracketing Dir. 1:  Delta = [-6.46e-05, 5.29e-07]   Objfun = -0.00275
#     Linescan in Dir. 1:    Delta = -3.17e-05   Objfun = 0.0113
#
#     Bracketing Dir. 2:  Delta = [-0.000169, 9.95e-06]   Objfun = -0.000617
#     Linescan in Dir. 2:    Delta = -7.98e-05   Objfun = 0.0111
#     Updated ObjFun largest decrease 0.000.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0091: Final ObjFun = 0.0111
#
# Iteration 0092/1000
#     Bracketing Dir. 1:  Delta = [-1.29e-08, 1.64e-07]   Objfun = -0.00875
#     Linescan in Dir. 1:    Delta = 0   Objfun = -0.00875
#     Updated ObjFun largest decrease 0.020.
#
#     Bracketing Dir. 2:  Delta = [-1.36e-09, 5.19e-10]   Objfun = -0.00875
#     Linescan in Dir. 2:    Delta = -3.25e-10   Objfun = 0.0027
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0092: Final ObjFun = 0.0027
#
# Iteration 0093/1000
#     Bracketing Dir. 1:  Delta = [-0.00552, 2.81e-08]   Objfun = 0.00104
#     Linescan in Dir. 1:    Delta = -0.000729   Objfun = 0.0238
#
#     Bracketing Dir. 2:  Delta = [-2.5e-06, 0.000802]   Objfun = 5.99e-06
#     Linescan in Dir. 2:    Delta = 0.000403   Objfun = 0.00537
#     Updated ObjFun largest decrease 0.018.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0093: Final ObjFun = 0.00537
#
# Iteration 0094/1000
#     Bracketing Dir. 1:  Delta = [-3.48e-07, 0.00176]   Objfun = 0.00248
#     Linescan in Dir. 1:    Delta = 0.000652   Objfun = 0.0108
#
#     Bracketing Dir. 2:  Delta = [-1.29e-06, 6.25e-06]   Objfun = -0.0066
#         # outliers removed = 2,
#     Linescan in Dir. 2:    Delta = 9.12e-07   Objfun = 0.00876
#     Updated ObjFun largest decrease 0.002.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# ...
#     Linescan in Dir. 2:    Delta = -4.75e-18   Objfun = 0.00966
#     Updated ObjFun largest decrease 0.012.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0212: Final ObjFun = 0.00966
#
# Iteration 0213/1000
#     Bracketing Dir. 1:  Delta = [-2.54e-13, 4.1e-13]   Objfun = -0.000636
#     Linescan in Dir. 1:    Delta = -3.86e-15   Objfun = 0.0136
#
#     Bracketing Dir. 2:  Delta = [-1.46e-09, 2.14e-10]   Objfun = 0.00106
#     Linescan in Dir. 2:    Delta = -6.5e-10   Objfun = 0.00649
#     Updated ObjFun largest decrease 0.007.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0213: Final ObjFun = 0.00649
#
# Iteration 0214/1000
#     Bracketing Dir. 1:  Delta = [-1.22e-09, 5.61e-08]   Objfun = -0.00604
#     Linescan in Dir. 1:    Delta = 7.15e-09   Objfun = 0.00699
#
#     Bracketing Dir. 2:  Delta = [-6.42e-11, 1.37e-11]   Objfun = -0.00348
#     Linescan in Dir. 2:    Delta = -3.01e-11   Objfun = 0.0171
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0214: Final ObjFun = 0.0171
#
# Iteration 0215/1000
#     Bracketing Dir. 1:  Delta = [-1.6e-18, 1.17e-17]   Objfun = -0.00386
#     Linescan in Dir. 1:    Delta = 5.39e-18   Objfun = 0.00262
#     Updated ObjFun largest decrease 0.015.
#
#     Bracketing Dir. 2:  Delta = [-1.21e-12, 1.02e-09]   Objfun = 0.000648
#     Linescan in Dir. 2:    Delta = 6.13e-11   Objfun = 0.0195
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0215: Final ObjFun = 0.0195
#
# Iteration 0216/1000
#     Bracketing Dir. 1:  Delta = [-4.72e-11, 8e-10]   Objfun = -0.00393
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0   Objfun = -0.00393
#     Updated ObjFun largest decrease 0.023.
#
#     Bracketing Dir. 2:  Delta = [-2.06e-19, 7.89e-20]   Objfun = -0.00393
#     Linescan in Dir. 2:    Delta = -4.82e-20   Objfun = 0.00234
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 1.000
# End of iteration 0216: Final ObjFun = 0.00234
#
# Iteration 0217/1000
#     Bracketing Dir. 1:  Delta = [-1.31e-19, 3.02e-18]   Objfun = -0.00174
#     Linescan in Dir. 1:    Delta = 1.06e-19   Objfun = 0.00127
#     Updated ObjFun largest decrease 0.001.
#
#     Bracketing Dir. 2:  Delta = [-5.83e-07, 1.27e-08]   Objfun = -0.00688
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -2.99e-07   Objfun = 0.00957
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0217: Final ObjFun = 0.00957
#
# Iteration 0218/1000
#     Bracketing Dir. 1:  Delta = [-4.16e-18, 3.89e-14]   Objfun = -0.00117
#     Linescan in Dir. 1:    Delta = 1.54e-14   Objfun = 0.0168
#
#     Bracketing Dir. 2:  Delta = [-1.75e-17, 3.89e-14]   Objfun = -0.0109
#     Linescan in Dir. 2:    Delta = 1.28e-14   Objfun = 0.00767
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced: max dot product 1.000
# End of iteration 0218: Final ObjFun = 0.00767
#
# Iteration 0219/1000
#     Bracketing Dir. 1:  Delta = [-4.79e-18, 8.49e-14]   Objfun = -0.00768
#     Linescan in Dir. 1:    Delta = 3.98e-14   Objfun = 0.00187
#     Updated ObjFun largest decrease 0.006.
#
#     Bracketing Dir. 2:  Delta = [-1.01e-16, 5.9e-16]   Objfun = -0.00645
#     Linescan in Dir. 2:    Delta = 0   Objfun = -0.00645
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0219: Final ObjFun = -0.00645
#
# Iteration 0220/1000
#     Bracketing Dir. 1:  Delta = [-6.82e-19, 1.79e-18]   Objfun = -0.00645
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 5.95e-19   Objfun = 0.0101
#
#     Bracketing Dir. 2:  Delta = [-3.32e-12, 1.53e-10]   Objfun = -0.00293
#     Linescan in Dir. 2:    Delta = 3.36e-11   Objfun = 0.00222
#     Updated ObjFun largest decrease 0.008.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0220: Final ObjFun = 0.00222
#
# Iteration 0221/1000
#     Bracketing Dir. 1:  Delta = [-7.86e-19, 6.94e-17]   Objfun = -0.00854
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 2.63e-17   Objfun = 0.0143
#
#     Bracketing Dir. 2:  Delta = [-1.15e-19, 5.37e-19]   Objfun = -0.0025
#     Linescan in Dir. 2:    Delta = 2.07e-19   Objfun = 0.0055
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0221: Final ObjFun = 0.0055
#
# Iteration 0222/1000
#     Bracketing Dir. 1:  Delta = [-1.05e-15, 1.69e-15]   Objfun = -0.0108
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 2.53e-16   Objfun = -0.00559
#     Updated ObjFun largest decrease 0.011.
#
#     Bracketing Dir. 2:  Delta = [-1.81e-19, 6.91e-20]   Objfun = -0.00559
#     Linescan in Dir. 2:    Delta = -4.28e-20   Objfun = 0.0113
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 1.000
# End of iteration 0222: Final ObjFun = 0.0113
#
# Iteration 0223/1000
#     Bracketing Dir. 1:  Delta = [-7.48e-18, 6.39e-19]   Objfun = -2.08e-05
#     Linescan in Dir. 1:    Delta = -2.92e-18   Objfun = 0.00897
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-2.28e-15, 4.85e-17]   Objfun = 0.00221
#     Linescan in Dir. 2:    Delta = -1.18e-15   Objfun = 0.0113
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0223: Final ObjFun = 0.0113
#
# Iteration 0224/1000
#     Bracketing Dir. 1:  Delta = [-4.99e-15, 2.62e-16]   Objfun = -0.00172
#     Linescan in Dir. 1:    Delta = -2.18e-15   Objfun = 0.0173
#
#     Bracketing Dir. 2:  Delta = [-1.19e-18, 1.3e-14]   Objfun = 0.00215
#     Linescan in Dir. 2:    Delta = 5.9e-15   Objfun = 0.00873
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0224: Final ObjFun = 0.00873
#
# Iteration 0225/1000
#     Bracketing Dir. 1:  Delta = [-1.58e-15, 2.56e-15]   Objfun = -0.00197
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = 0   Objfun = -0.00197
#     Updated ObjFun largest decrease 0.011.
#
#     Bracketing Dir. 2:  Delta = [-2.47e-20, 3.06e-20]   Objfun = -0.0102
#     Linescan in Dir. 2:    Delta = 2.95e-21   Objfun = 0.00393
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0225: Final ObjFun = 0.00393
#
# Iteration 0226/1000
#     Bracketing Dir. 1:  Delta = [-1.62e-13, 1.68e-08]   Objfun = -0.00666
#     Linescan in Dir. 1:    Delta = 2.94e-09   Objfun = 0.00725
#
#     Bracketing Dir. 2:  Delta = [-2.4e-17, 7.77e-17]   Objfun = -0.00402
#     Linescan in Dir. 2:    Delta = 2.42e-17   Objfun = 0.012
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0226: Final ObjFun = 0.012
#
# Iteration 0227/1000
#     Bracketing Dir. 1:  Delta = [-3.84e-20, 4.88e-19]   Objfun = -0.00284
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 0   Objfun = -0.00309
#     Updated ObjFun largest decrease 0.015.
#
#     Bracketing Dir. 2:  Delta = [-2.78e-20, 3.42e-18]   Objfun = -0.00309
#     Linescan in Dir. 2:    Delta = 1.9e-19   Objfun = 0.00384
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0227: Final ObjFun = 0.00384
#
# Iteration 0228/1000
#     Bracketing Dir. 1:  Delta = [-2.95e-13, 4.78e-13]   Objfun = -0.00615
#     Linescan in Dir. 1:    Delta = 8.61e-14   Objfun = 0.00162
#     Updated ObjFun largest decrease 0.002.
#
#     Bracketing Dir. 2:  Delta = [-1.03e-18, 6.29e-15]   Objfun = -0.00289
#     Linescan in Dir. 2:    Delta = 3.24e-15   Objfun = 0.00133
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0228: Final ObjFun = 0.00133
#
# Iteration 0229/1000
#     Bracketing Dir. 1:  Delta = [-6.44e-13, 2.91e-16]   Objfun = -0.000402
#     Linescan in Dir. 1:    Delta = -3.36e-13   Objfun = 0.00736
#
#     Bracketing Dir. 2:  Delta = [-5.63e-05, 6.42e-13]   Objfun = 0.00155
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -3.44e-05   Objfun = 0.0213
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0229: Final ObjFun = 0.0213
#
# Iteration 0230/1000
#     Bracketing Dir. 1:  Delta = [-2.44e-16, 1.22e-18]   Objfun = -0.00353
#     Linescan in Dir. 1:    Delta = -1.2e-16   Objfun = 0.00446
#     Updated ObjFun largest decrease 0.017.
#
#     Bracketing Dir. 2:  Delta = [-3.81e-07, 4.53e-10]   Objfun = -0.000364
#         # outliers removed = 1,
#     Linescan in Dir. 2:    Delta = -1.97e-07   Objfun = 0.00292
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: False
#         cond 2nd deriv.: True
# End of iteration 0230: Final ObjFun = 0.00292
#
# Iteration 0231/1000
#     Bracketing Dir. 1:  Delta = [-6.35e-19, 6.24e-19]   Objfun = -0.000148
#     Linescan in Dir. 1:    Delta = -1.46e-20   Objfun = 0.0102
#
#     Bracketing Dir. 2:  Delta = [-1.65e-18, 1.17e-12]   Objfun = -0.00062
#     Linescan in Dir. 2:    Delta = 6.53e-14   Objfun = 0.00924
#     Updated ObjFun largest decrease 0.001.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0231: Final ObjFun = 0.00924
#
# Iteration 0232/1000
#     Bracketing Dir. 1:  Delta = [-5.29e-19, 8.89e-18]   Objfun = -0.00717
#     Linescan in Dir. 1:    Delta = 0   Objfun = -0.00717
#     Updated ObjFun largest decrease 0.016.
#
#     Bracketing Dir. 2:  Delta = [-2e-19, 4.27e-21]   Objfun = -0.00717
#     Linescan in Dir. 2:    Delta = -1.19e-19   Objfun = 0.0024
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0232: Final ObjFun = 0.0024
#
# Iteration 0233/1000
#     Bracketing Dir. 1:  Delta = [-1.58e-19, 1.76e-19]   Objfun = 0.000147
#     Linescan in Dir. 1:    Delta = 2.45e-21   Objfun = 0.0125
#
#     Bracketing Dir. 2:  Delta = [-2.99e-18, 4.41e-19]   Objfun = -0.00672
#     Linescan in Dir. 2:    Delta = -8.48e-19   Objfun = 0.00848
#     Updated ObjFun largest decrease 0.004.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0233: Final ObjFun = 0.00848
#
# Iteration 0234/1000
#     Bracketing Dir. 1:  Delta = [-2.36e-18, 1.44e-14]   Objfun = 0.000198
#     Linescan in Dir. 1:    Delta = 8.04e-16   Objfun = 0.0128
#
#     Bracketing Dir. 2:  Delta = [-3.92e-09, 5.92e-05]   Objfun = 0.00317
#     Linescan in Dir. 2:    Delta = 1.93e-05   Objfun = 0.017
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0234: Final ObjFun = 0.017
#
# Iteration 0235/1000
#     Bracketing Dir. 1:  Delta = [-3.87e-12, 4.01e-07]   Objfun = 0.00117
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 1.99e-07   Objfun = -0.00951
#     Updated ObjFun largest decrease 0.027.
#
#     Bracketing Dir. 2:  Delta = [-7.95e-19, 3.04e-19]   Objfun = -0.00951
#     Linescan in Dir. 2:    Delta = -1.98e-19   Objfun = 0.0128
#
#     Checking extension point.
#     Dir. 1 not replaced: max dot product 1.000
# End of iteration 0235: Final ObjFun = 0.0128
#
# Iteration 0236/1000
#     Bracketing Dir. 1:  Delta = [-5.58e-16, 3.11e-17]   Objfun = -0.00448
#     Linescan in Dir. 1:    Delta = -2.5e-16   Objfun = 0.00595
#     Updated ObjFun largest decrease 0.007.
#
#     Bracketing Dir. 2:  Delta = [-3.82e-15, 4.55e-18]   Objfun = -0.00187
#     Linescan in Dir. 2:    Delta = -1.91e-15   Objfun = 0.012
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0236: Final ObjFun = 0.012
#
# Iteration 0237/1000
#     Bracketing Dir. 1:  Delta = [-9.9e-18, 2.69e-12]   Objfun = -0.00194
#     Linescan in Dir. 1:    Delta = 1.22e-12   Objfun = 0.013
#
#     Bracketing Dir. 2:  Delta = [-3.31e-10, 1.13e-17]   Objfun = -0.0014
#     Linescan in Dir. 2:    Delta = -1.42e-10   Objfun = 0.0221
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0237: Final ObjFun = 0.0221
#
# Iteration 0238/1000
#     Bracketing Dir. 1:  Delta = [-2.69e-18, 1.29e-08]   Objfun = -0.0132
#         # outliers removed = 2,
#     Linescan in Dir. 1:    Delta = 1.89e-09   Objfun = 0.00496
#     Updated ObjFun largest decrease 0.017.
#
#     Bracketing Dir. 2:  Delta = [-4.5e-19, 1.96e-20]   Objfun = -0.0119
#     Linescan in Dir. 2:    Delta = -2.06e-19   Objfun = 0.00401
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0238: Final ObjFun = 0.00401
#
# Iteration 0239/1000
#     Bracketing Dir. 1:  Delta = [-1.89e-15, 6.12e-15]   Objfun = -0.00497
#     Linescan in Dir. 1:    Delta = 2.43e-15   Objfun = 0.0145
#
#     Bracketing Dir. 2:  Delta = [-1.04e-13, 1.55e-14]   Objfun = -0.00528
#     Linescan in Dir. 2:    Delta = -4.75e-14   Objfun = 0.0104
#     Updated ObjFun largest decrease 0.004.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0239: Final ObjFun = 0.0104
#
# Iteration 0240/1000
#     Bracketing Dir. 1:  Delta = [-3.93e-17, 2.46e-20]   Objfun = -0.0042
#     Linescan in Dir. 1:    Delta = -1.94e-17   Objfun = 0.0132
#
#     Bracketing Dir. 2:  Delta = [-3.18e-19, 7.79e-21]   Objfun = -0.00205
#     Linescan in Dir. 2:    Delta = -1.63e-19   Objfun = 0.000824
#     Updated ObjFun largest decrease 0.012.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# End of iteration 0240: Final ObjFun = 0.000824
#
# Iteration 0241/1000
#     Bracketing Dir. 1:  Delta = [-2.99e-21, 1.54e-15]   Objfun = -0.00357
#     Linescan in Dir. 1:    Delta = 3.56e-16   Objfun = 0.0161
#
#     Bracketing Dir. 2:  Delta = [-2.05e-20, 6.82e-19]   Objfun = -0.0102
#     Linescan in Dir. 2:    Delta = 1.56e-19   Objfun = 0.00743
#     Updated ObjFun largest decrease 0.009.
#
#     Checking extension point.
#     Dir. 2 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0241: Final ObjFun = 0.00743
#
# Iteration 0242/1000
#     Bracketing Dir. 1:  Delta = [-1.04e-17, 2.73e-17]   Objfun = -0.000747
#         # outliers removed = 1,
#     Linescan in Dir. 1:    Delta = 6.98e-18   Objfun = 0.0108
#
#     Bracketing Dir. 2:  Delta = [-4.01e-18, 2.3e-14]   Objfun = -0.00144
#     Linescan in Dir. 2:    Delta = 7.3e-15   Objfun = 0.0162
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: True
# End of iteration 0242: Final ObjFun = 0.0162
#
# Iteration 0243/1000
#     Bracketing Dir. 1:  Delta = [-7.32e-15, 7.32e-15]   Objfun = 0.000755
#     Linescan in Dir. 1:    Delta = 1.98e-16   Objfun = 0.00472
#     Updated ObjFun largest decrease 0.011.
#
#     Bracketing Dir. 2:  Delta = [-4.36e-20, 4.23e-11]   Objfun = -0.023
#     Linescan in Dir. 2:    Delta = 2.36e-12   Objfun = 0.0224
#
#     Checking extension point.
#     Dir. 1 not replaced:
#         func0 >= func_e: True
#         cond 2nd deriv.: False
# Exiting: Maximum number of evaluations reached.
# End of iteration 0243: Final ObjFun = 0.0224
#
#  Finished!
# Number of iterations: 0243
# Number of evaluations: 10023
# f_0 = 404
# f_min = -0.023
# f_min/f0 = -5.7e-05

# %%
fig, ax = opt.plot_history()

# %%
fig, ax = opt.plot_knobspace_slice()

# %%
positions_evaluated = np.array(opt.positions_evaluated)
positions_cumulated_optimum = opt.get_cumulated_optimum()[1]

fig, ax = mplt.subplots(figsize=(8,8))

Xgrid, Ygrid = np.meshgrid(np.linspace(-4, 4, 201), np.linspace(-4, 4, 201) )

Zgrid = np.zeros_like(Xgrid)
for i in range(Xgrid.shape[0]):
    for j in range(Xgrid.shape[1]):
        pos = [Xgrid[i, j], Ygrid[i, j]]
        Zgrid[i, j] = opt.objective_function(pos=pos)
Zgrid = np.log(Zgrid+1)

ax.pcolormesh(Xgrid, Ygrid, Zgrid)
ax.contour(Xgrid, Ygrid, Zgrid, levels=10, colors='black')
ax.set_xlabel('x0')
ax.set_ylabel('x1')


# Add all evaluations
ax.plot(positions_evaluated[:, 0], positions_evaluated[:, 1], 'o', color='white', alpha=0.4, mfc='none')

# ax.plot(positions_cumulated_optimum[:, 0],
#         positions_cumulated_optimum[:, 1],
#         color='red', alpha=0.4, marker='x')

for i in range(len(positions_cumulated_optimum) - 1):
    ax.annotate(
        '',
        xy=(positions_cumulated_optimum[i + 1, 0], positions_cumulated_optimum[i + 1, 1]),
        xytext=(positions_cumulated_optimum[i, 0], positions_cumulated_optimum[i, 1]),
        arrowprops=dict(arrowstyle="->", color='red', lw=1)
    )
ax.scatter(1, 1, 50, marker='o', color='orange', label="True minimum")
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# # General considerations for online experiments

# %% [markdown]
# - RCDS is most adequate for small to moderate parameter space dimensions (up to 20 variables)
# - if objective is too noisy, consider averaging or taking the median
# - RCDS is a single objective box-constrained optimzation algorithm
#     - if, at any iteration, the algorithm proposes positions outside the variable limits indicated by the user, the positiosn are set to `nan`s and the objective function returns `nan`
#     - more general constraints can be achieved with barrier-methods
#     $$f(x) = \text{objective}(x) + \lambda ~ \text{constraint}(x)$$
#     - eg.: unit circle in param-space
#         $$\text{constraint(x)} = \text{max}(x_1^2 + x_2^2 - 1, 0)$$
# - multi-objective problems can be linearly combined into single objective with appropriate weights $w_i$
#     $$f(x) = \sum_i w_i \text{objective}_i(x) $$

# %% [markdown]
# ## Example of useage in real experiment with PVs

# %% [markdown]
# for more examples, check out
# - `lnls-fac/apsuite/commisslib/injbo_optimize_rcds.py`: optimization of injection effficiency at the Booster using positions & angles at the transport line, Booster ejection kicker strength, klystron 2 amplitude & phases and booster RF phase as optimization knobs
# - `lnls-fac/apsuite/commisslib/rcds_posang.py`: optimzation of injection efficiency at the storage ring using postions & angles, NLK kick strength as optimzation knobs (most simple example)
# - `lnls-fac/apsuite/commisslib/opt_septa_feedforward.py`: optimzation of septa feedforward
# - `lnls-fac/apsuite/commisslib/dynap_opt_rcds.py`: optimzation of storage ring dynamic aperture using sextuupole families as optimztion knobs

# %%
class OnlineOptProblemParams(RCDSParams):

    def __init__(self):
        """."""
        super().__init__()
        self.problem_ppty1 = None
        self.problem_ppty2 = None
        self.problem_ppty3 = None

# %%
KNOBS = ["posx", "posy", "angx", "angy"]
LIMS_UPPER = [+5., +5., +2., +2.]
LIMS_LOWER = [-5., -5., -2., -2.]

# %%
import time
from siriuspy.epics import PV


class OnlineOptProblem(RCDS):
    """."""
    def __init__(self, use_thread=True, isonline=True):
        """."""
        RCDS.__init__(use_thread, isonline)
        self.params = OnlineOptProblemParams()

        if self.isonline:
            self._create_connections()

    def set_positions(self, positions):
        """Set position (parameter space) to setpoint PVs.

        Args:
            positions (array, list): posx, posy, angx, angy
        """
        if positions is None:
            return

        posx = self.pvs["posx_sp"]
        posy = self.pvs["posy_sp"]
        angx = self.pvs["angx_sp"]
        angy = self.pvs["angy_sp"]
        posx.value, posy.value, angx.value, angy.value = positions
        self.wait_()


    def get_positions(self):
        """Get parameter-spcae position from PVs readback.

        Returns:
            list: with posx, posy, angx, angy
        """
        posx = self.pvs["posx_rb"].value
        posy = self.pvs["posy_rb"].value
        angx = self.pvs["angx_rb"].value
        angy = self.pvs["angy_rb"].value
        return [posx, posy, angx, angy]

    def objective_function(self, pos):
        """Optimization problem objective function.

        Args:
            pos (array, list): parameter space positions
            (posx, posy, angx, angy)

        Returns:
            float: objective function
        """
        self.set_positions(pos)
        obj = self.pvs["detector_measurment_rb"]
        # RCDS is a minimization algorithm.
        # for maximization, set obj = -obj
        return obj

    def _create_connections(self):
        pvname = ""
        self.pvs["posx_sp"] = PV(pvname)
        self.pvs["posy_sp"] = PV(pvname)
        self.pvs["angx_sp"] = PV(pvname)
        self.pvs["angy_sp"] = PV(pvname)
        self.pvs["posx_rb"] = PV(pvname)
        self.pvs["posy_rb"] = PV(pvname)
        self.pvs["angx_rb"] = PV(pvname)
        self.pvs["angy_rb"] = PV(pvname)

        self.pvs["detector_measurement_rb"] = PV(pvname)

    def wait_(self):
        """Wait PVs reach setpoint."""
        pv_response_time = 2  # [s]
        print('waiting pvs')
        time.sleep(pv_response_time)
        # alternatively, you can check if the
        # desired PVs readback or mon have reached the
        # desired values set up to a tolerance value

    def measure_objfunc_noise(self, nr_meas=5):
        """Evaluate objectuve function to estimate experimental noise.

        Args:
            nr_meas (int, optional): Nr. of measurements. Defaults to 5.
        """
        meas = []
        pos = self.get_positions()
        for _ in range(nr_meas):
            meas.append(self.objective_function(pos))
        mean, noise = np.mean(meas), np.std(meas)
        print(f"objective function mean:  {mean:.3f}")
        print(f"objective function noise: {noise:.3f}")
        self.data['measured_objfuncs_for_noise'] = meas
        self.data['measured_noise_level'] = noise
        return

# %% [markdown]
# **Instantiate optmization object.**
# - `isonline=True` to create PVs or devices connections
# - `use_thread=True` to launch cell in a different thread, allowing use of the notebook while optimzation runs (plotting history, checking data, processing data already taken, etc)

# %%
opt = OnlineOptProblem(isonline=True, use_thread=True)

# %% [markdown]
# **Set parameters**
#
# Noise measurement & estimation
# - initially, set any value for the `noise_level`.
# - then, take measurements of the objective functin noise to get an estimate
# - update `noise_level` with the measured value
#
# Initial postion
# - you can choose to start the optimzation from the current positions, or from the average postion in param space or in the origin of it.
#
# Initial search directions
# - this is a matrix. Each row corresponds to a direction vector along which the minimum will be scanned during the fist RCDS iteration. After that, these direcetions may change, according to Poweel's method for updating search directions.

# %%
# problem-specific params
opt.params.limit_lower = LIMS_LOWER
opt.params.limit_upper = LIMS_UPPER

# RCDS params
opt.params.max_number_evals = 500
opt.params.max_number_iters = 10
opt.params.initial_stepsize = 0.0100
opt.params.noise_level = 1e-3  # set initial guesse, then measure noise &
                               # update it here
opt.params.tolerance = 1e-4


opt.params.initial_position = np.random.uniform(
    low=opt.params.limit_lower,
    high=opt.params.limit_upper
)
# or
# current_pos = opt.get_positions()
# opt.params.initial_position = current_pos

param_space_dim = len(opt.params.limit_lower)
opt.params.initial_search_directions = np.eye(param_space_dim)

# %%
opt.start()

# %%
opt.plot_history()

# %%
fname = "optimization_run1"
opt.save_data(fname=fname, overwrite=False)

# %%
opt.load_and_apply(fname)

# %%
opt.data.keys()
